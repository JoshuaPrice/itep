# %%
# File name: genLabeledLoops.py
# Author: Joshua Price
# Date created: 04/03/2018
# Date last modified: 04/11/2018
# Python Version: 2.7

# Purpose: addTadCols and addEPCols annotates known contacts with TAD labels and enhancer/promoter labels
	# addTadCols: takes BedTool with TAD information (tads) and df with loops information, adds two TAD cols to loops df
	# addEPCols: takes BedTool with regulatory information (regs) and, df with loops information, adds two reg cols to loops df
	# mergeLabeledLoops: merges two dfs and saves single df with loops, TAD, and reg info into .csv file
	# locFilter: method for pbt filtering, returns true if feature encapsulates given bp info
	# approxLocFilter: method for pbt filtering, returns true if feature overlaps with given bp info
	# containsPromoter: method for pbt filtering, returns true if feature labeled promoter or promoter proximal region
	# containsEnhancer: method for pbt filtering, returns true if feature labeled enhancer
	# extractLoopInfo: helper function that extracts useful contact info from df row
	# bedCopyAndLen: helper function to get BedTool length without erasing it

import pybedtools as pbt
import pandas as pd
import numpy as np

def addTadCols(tads, loops):
	# Purpose: takes BedTool with TAD information (tads) and df with loops information, adds two TAD cols to loops df
	# Inputs: 
		# tads: BedTool with TAD information in bed format (chr#, startBp, endBp, name, score, ...)
		# loops: pd df (no header) with chrA#, startBpA, endBpA, chrB#, startBpB, endBpB, score
	# Outputs:
		# loops: pd df with two new columns (tadA, tadB) populated with TAD IDs corresponding to loops

	# Add new columns to loops df
	loops["tadA"] = ""
	loops["tadB"] = ""

	# Initialize counters used to produce early report
	numLoops, numIntra, numProblem = 0, 0, 0 

	for idx, row in loops.iterrows():
		chrA, startBpA, endBpA, chrB, startBpB, endBpB = extractLoopInfo(row)

		# tadAInfo contains TAD(s) that encapsulate the contact point
		tadAInfo = tads[(tads['chr'] == chrA) & (tads['startbp'] < startBpA) & (tads['endbp'] > endBpA)]
		tadAInfoLen = tadAInfo.shape[0]
		tadAInfo.reset_index(drop=True, inplace=True)

		# if contact point encapsulated by TAD, add that TAD label to df
		if tadAInfoLen > 0: 
			loops.loc[idx, "tadA"] = tadAInfo.loc[0, "name"]
		else: 
			loops.loc[idx, "tadA"] = np.NaN

		# tadBInfo contains TAD(s) that encapsulate the contact point
		tadBInfo = tads[(tads['chr'] == chrB) & (tads['startbp'] < startBpB) & (tads['endbp'] > endBpB)]
		tadBInfoLen = tadBInfo.shape[0]
		tadBInfo.reset_index(drop=True, inplace=True)

		# if contact point encapsulated by TAD, add that TAD label to df
		if tadBInfoLen > 0: 
			loops.loc[idx, "tadB"] = tadBInfo.loc[0, "name"]

		# if both contact points in same TAD (and in a TAD at all), note as intra-TAD
		if loops.loc[idx, "tadA"] == loops.loc[idx, "tadB"] and tadAInfoLen > 0:
			numIntra += 1
		
		# if either contact point is not within a TAD, note as TADless ('problem') contact
		if tadAInfoLen == 0 or tadBInfoLen == 0:
			numProblem += 1

		numLoops += 1
		# print "Percent intra-TAD so far: ", float(numIntra)/(numLoops-numProblem)
		print "Rows completed: ", numLoops

	# Provide initial report about fraction of intra-TAD contacts and fraction of TADless contacts
	print "Percent intra-TAD: ", float(numIntra)/(numLoops-numProblem)
	print "Percent overlapping with TAD boundary (not counted in inter/intra): ", float(numProblem) / numLoops
	print loops
	return loops

def addEPCols(regs, loops):
	# Purpose: takes BedTool with regulatory information (regs) and df with loops information, adds two reg cols to loops df
	# Inputs: 
		# regs: BedTool with regulatory information in bed format (chr#, startBp, endBp, name)
		# loops: pd df (no header) with chrA#, startBpA, endBpA, chrB#, startBpB, endBpB, score, (tadA), (tadB)
	# Outputs:
		# loops: pd df with two new columns (regA, regB) populated with regulatory feature IDs corresponding to loops
	# Add new columns to loops df	
	loops["regA"] = ""
	loops["regB"] = ""
	loops["Int_Status"] = ""

	# Initialize counters used to produce early report
	numLoops, numEE, numPP, numEP, numProblem = 0, 0, 0, 0, 0

	for idx, row in loops.iterrows():
		chrA, startBpA, endBpA, chrB, startBpB, endBpB = extractLoopInfo(row)
		chrA = 'chr' + str(chrA)
		chrB = 'chr' + str(chrB)

		# regAInfo contains regulatory labels of regions that overlap with the contact point        
		regAInfo = regs[(((regs['chr'] == chrA) & (regs['startbp'] < startBpA) \
				& (regs['endbp'] > startBpA)) | \
					((regs['chr'] == chrA) & (regs['startbp'] < endBpA) & (regs['endbp'] > endBpA)) | \
					((regs['chr'] == chrA) & (regs['startbp'] > startBpA) & (regs['endbp'] < endBpA)))]

		regAInfoLen = regAInfo.shape[0]
		regAInfo.reset_index(drop=True, inplace=True)

		# labels for whether a promoter or enhancer labeled region overlaps with the contact point
		promoterPresentA = regAInfo[regAInfo['feature_type'] == 'feature_type=Promoter'].shape[0] > 0
		enhancerPresentA = regAInfo[regAInfo['feature_type'] == 'feature_type=Enhancer'].shape[0] > 0
        
		# add regulatory label to df as appropriate (EP = both enhancer AND promoter, N = neither)
		if promoterPresentA and enhancerPresentA:
			loops.loc[idx, "regA"] = 'EP'
		elif promoterPresentA:
			loops.loc[idx, "regA"] = 'P'
		elif enhancerPresentA:
			loops.loc[idx, "regA"] = 'E'
		else:
			loops.loc[idx, "regA"] = 'N'

		# regBInfo contains regulatory labels of regions that overlap with the contact point
		regBInfo = regs[(((regs['chr'] == chrB) & (regs['startbp'] < startBpB) \
				& (regs['endbp'] > startBpB)) | \
					((regs['chr'] == chrB) & (regs['startbp'] < endBpB) & (regs['endbp'] > endBpB)) | \
					((regs['chr'] == chrB) & (regs['startbp'] > startBpB) & (regs['endbp'] < endBpB)))]
        
		regBInfoLen = regBInfo.shape[0]
		regBInfo.reset_index(drop=True, inplace=True)

		# labels for whether a promoter or enhancer labeled region overlaps with the contact point
		promoterPresentB = regBInfo[regBInfo['feature_type'] == 'feature_type=Promoter'].shape[0] > 0
		enhancerPresentB = regBInfo[regBInfo['feature_type'] == 'feature_type=Enhancer'].shape[0] > 0
        
		# add regulatory label to df as appropriate (EP = both enhancer AND promoter, N = neither)
		if promoterPresentB and enhancerPresentB:
			loops.loc[idx, "regB"] = 'EP'
		elif promoterPresentB:
			loops.loc[idx, "regB"] = 'P'
		elif enhancerPresentB:
			loops.loc[idx, "regB"] = 'E'
		else:
			loops.loc[idx, "regB"] = 'N'

		# note as EP if one contact point contains E/EP and other contains P/EP
		if (enhancerPresentA and promoterPresentB) or (promoterPresentA and enhancerPresentB):
			isEP = True
		else:
			isEP = False

		# note as same TAD if identical non-empty TAD labels
		if loops.loc[idx, 'tadA'] == loops.loc[idx, 'tadB'] and not pd.isnull(loops.loc[idx, 'tadA']):
			sameTAD = True
		else: 
			sameTAD = False
        
		# if either TAD label is empty, mark contact row as TAD-less
		if pd.isnull(loops.loc[idx, 'tadA']) or pd.isnull(loops.loc[idx, 'tadB']):
			isTADless = True
		else:
			isTADless = False

		# add appropriate label to "EP_Status" col in row, N means non-EP
		if isEP and sameTAD:
			loops.loc[idx, "Int_Status"] = "intraEP"
		elif isEP and not sameTAD and not isTADless:
			loops.loc[idx, "Int_Status"] = "interEP"
		elif not isEP and sameTAD:
			loops.loc[idx, "Int_Status"] = "intraN"
		elif not isEP and not sameTAD and not isTADless:
			loops.loc[idx, "Int_Status"] = "interN"
		elif isEP and isTADless:
			loops.loc[idx, "Int_Status"] = "tadlessEP"
		elif not isEP and isTADless:
			loops.loc[idx, "Int_Status"] = "tadlessN"

		# Count contacts for initial report
		if (promoterPresentA and enhancerPresentB) or (enhancerPresentA and promoterPresentB):
			numEP += 1
		if enhancerPresentA and enhancerPresentB:
			numEE += 1
		if promoterPresentA and promoterPresentB:
			numPP += 1
		numLoops += 1

		# Provide initial report about regulatory distribution of loops
		# print "Percent EE: ", float(numEE)/(numLoops)
		# print "Percent PP: ", float(numPP)/(numLoops)
		# print "Percent EP: ", float(numEP)/(numLoops)
		print "Rows completed: ", numLoops

	# returned original loops df with cols (regA and regB) added
	return loops

def mergeLabeledLoops(tadLabelsDf, regLabelsDf):
	# Purpose: takes BedTool with regulatory information (regs) and df with loops information, adds two reg cols to loops df
	# Inputs: 
		# regs: BedTool with regulatory information in bed format (chr#, startBp, endBp, name)
		# loops: pd df (no header) with chrA#, startBpA, endBpA, chrB#, startBpB, endBpB, score, (tadA), (tadB)
	# Outputs:
		# loops: pd df with two new columns (regA, regB) populated with regulatory feature IDs corresponding to loops

	wholeLabeledDf = pd.concat([tadLabelsDf, regLabelsDf['regA'], \
		regLabelsDf['regB']], axis=1)
	# wholeLabeledDf.to_csv('/data2/josh/expCH12/labeled_loops.csv', index=True, sep='\t', header=True)
	return wholeLabeledDf

def locFilter(feature, chrom, startBp, endBp):
	# pybedtools filter function: Returns True if feature overlaps with contact
	return str(feature.chrom) == chrom and feature.start < startBp and feature.end > endBp

def approxLocFilter(feature, chrom, startBp, endBp):
	# pybedtools filter function: Returns True if feature overlaps with contact
	chrom = 'chr' + str(chrom)
	return str(feature.chrom) == chrom and ((feature.start < startBp and feature.end > startBp) \
		or (feature.start < endBp and feature.end > endBp)
		or (feature.start > startBp and feature.end < endBp))

def containsPromoter(feature):
	# pybedtools filter function: Returns True if feature is promoter
	return feature.name == 'feature_type=Promoter'

def containsEnhancer(feature):
	# pybedtools filter function: Returns True if feature is enhancer
	return feature.name == 'feature_type=Enhancer'

def extractLoopInfo(row):
	# helper function: extracts bed-formatted information from pandas df row
	chrA = row["chrA"]
	chrA = chrA[3:] # remove 'chr'
	startBpA = row["startbpA"]
	endBpA = row["endbpA"]
	chrB = row["chrB"]
	chrB = chrB[3:] # remove 'chr'
	startBpB = row["startbpB"]
	endBpB = row["endbpB"]
	return chrA, startBpA, endBpA, chrB, startBpB, endBpB

def bedCopyAndLen(bTool):
	# helper function: copies bedTool to report length (lame but necessary with pybedtools)
	bToolCopy = bTool.saveas('btool.bed')
	bToolLen = len(bToolCopy)
	bTool = pbt.BedTool('btool.bed')
	return bTool, bToolLen

# %%
if __name__ == "__main__":
    
	# Use CH12 TADs BED file for now
	tadFile = '/data2/josh/expCH12/CH12_lieberman_intra_5kb_domains.bed'
	tads = pd.read_table(tadFile)
	tads.columns = ["chr", "startbp", "endbp", "name", "score", "dir", "startbpB", "endbpB", 'rgb']

# %%
	loopFile = '/data2/josh/expCH12/lieberman_loops_CH12.txt'
	loops = pd.read_csv(loopFile, sep="\t", header=None)
	loops.columns = ["chrA", "startbpA", "endbpA", "chrB", "startbpB", "endbpB", "score"]

# %%
	tadLabeledLoops = addTadCols(tads, loops)
	tadLabeledLoops.to_csv('/data2/josh/expCH12/tad_labeled_loops.csv', index=True, sep='\t', header=True)
# Out:
# Rows completed:  1
# Rows completed:  2
# Rows completed:  3
# Rows completed:  4
# Rows completed:  5
# Rows completed:  6
# Rows completed:  7
# Rows completed:  8
# Rows completed:  9
# Rows completed:  10
# Rows completed:  11
# Rows completed:  12
# Rows completed:  13
# Rows completed:  14
# Rows completed:  15
# Rows completed:  16
# Rows completed:  17
# Rows completed:  18
# Rows completed:  19
# Rows completed:  20
# Rows completed:  21
# Rows completed:  22
# Rows completed:  23
# Rows completed:  24
# Rows completed:  25
# Rows completed:  26
# Rows completed:  27
# Rows completed:  28
# Rows completed:  29
# Rows completed:  30
# Rows completed:  31
# Rows completed:  32
# Rows completed:  33
# Rows completed:  34
# Rows completed:  35
# Rows completed:  36
# Rows completed:  37
# Rows completed:  38
# Rows completed:  39
# Rows completed:  40
# Rows completed:  41
# Rows completed:  42
# Rows completed:  43
# Rows completed:  44
# Rows completed:  45
# Rows completed:  46
# Rows completed:  47
# Rows completed:  48
# Rows completed:  49
# Rows completed:  50
# Rows completed:  51
# Rows completed:  52
# Rows completed:  53
# Rows completed:  54
# Rows completed:  55
# Rows completed:  56
# Rows completed:  57
# Rows completed:  58
# Rows completed:  59
# Rows completed:  60
# Rows completed:  61
# Rows completed:  62
# Rows completed:  63
# Rows completed:  64
# Rows completed:  65
# Rows completed:  66
# Rows completed:  67
# Rows completed:  68
# Rows completed:  69
# Rows completed:  70
# Rows completed:  71
# Rows completed:  72
# Rows completed:  73
# Rows completed:  74
# Rows completed:  75
# Rows completed:  76
# Rows completed:  77
# Rows completed:  78
# Rows completed:  79
# Rows completed:  80
# Rows completed:  81
# Rows completed:  82
# Rows completed:  83
# Rows completed:  84
# Rows completed:  85
# Rows completed:  86
# Rows completed:  87
# Rows completed:  88
# Rows completed:  89
# Rows completed:  90
# Rows completed:  91
# Rows completed:  92
# Rows completed:  93
# Rows completed:  94
# Rows completed:  95
# Rows completed:  96
# Rows completed:  97
# Rows completed:  98
# Rows completed:  99
# Rows completed:  100
# Rows completed:  101
# Rows completed:  102
# Rows completed:  103
# Rows completed:  104
# Rows completed:  105
# Rows completed:  106
# Rows completed:  107
# Rows completed:  108
# Rows completed:  109
# Rows completed:  110
# Rows completed:  111
# Rows completed:  112
# Rows completed:  113
# Rows completed:  114
# Rows completed:  115
# Rows completed:  116
# Rows completed:  117
# Rows completed:  118
# Rows completed:  119
# Rows completed:  120
# Rows completed:  121
# Rows completed:  122
# Rows completed:  123
# Rows completed:  124
# Rows completed:  125
# Rows completed:  126
# Rows completed:  127
# Rows completed:  128
# Rows completed:  129
# Rows completed:  130
# Rows completed:  131
# Rows completed:  132
# Rows completed:  133
# Rows completed:  134
# Rows completed:  135
# Rows completed:  136
# Rows completed:  137
# Rows completed:  138
# Rows completed:  139
# Rows completed:  140
# Rows completed:  141
# Rows completed:  142
# Rows completed:  143
# Rows completed:  144
# Rows completed:  145
# Rows completed:  146
# Rows completed:  147
# Rows completed:  148
# Rows completed:  149
# Rows completed:  150
# Rows completed:  151
# Rows completed:  152
# Rows completed:  153
# Rows completed:  154
# Rows completed:  155
# Rows completed:  156
# Rows completed:  157
# Rows completed:  158
# Rows completed:  159
# Rows completed:  160
# Rows completed:  161
# Rows completed:  162
# Rows completed:  163
# Rows completed:  164
# Rows completed:  165
# Rows completed:  166
# Rows completed:  167
# Rows completed:  168
# Rows completed:  169
# Rows completed:  170
# Rows completed:  171
# Rows completed:  172
# Rows completed:  173
# Rows completed:  174
# Rows completed:  175
# Rows completed:  176
# Rows completed:  177
# Rows completed:  178
# Rows completed:  179
# Rows completed:  180
# Rows completed:  181
# Rows completed:  182
# Rows completed:  183
# Rows completed:  184
# Rows completed:  185
# Rows completed:  186
# Rows completed:  187
# Rows completed:  188
# Rows completed:  189
# Rows completed:  190
# Rows completed:  191
# Rows completed:  192
# Rows completed:  193
# Rows completed:  194
# Rows completed:  195
# Rows completed:  196
# Rows completed:  197
# Rows completed:  198
# Rows completed:  199
# Rows completed:  200
# Rows completed:  201
# Rows completed:  202
# Rows completed:  203
# Rows completed:  204
# Rows completed:  205
# Rows completed:  206
# Rows completed:  207
# Rows completed:  208
# Rows completed:  209
# Rows completed:  210
# Rows completed:  211
# Rows completed:  212
# Rows completed:  213
# Rows completed:  214
# Rows completed:  215
# Rows completed:  216
# Rows completed:  217
# Rows completed:  218
# Rows completed:  219
# Rows completed:  220
# Rows completed:  221
# Rows completed:  222
# Rows completed:  223
# Rows completed:  224
# Rows completed:  225
# Rows completed:  226
# Rows completed:  227
# Rows completed:  228
# Rows completed:  229
# Rows completed:  230
# Rows completed:  231
# Rows completed:  232
# Rows completed:  233
# Rows completed:  234
# Rows completed:  235
# Rows completed:  236
# Rows completed:  237
# Rows completed:  238
# Rows completed:  239
# Rows completed:  240
# Rows completed:  241
# Rows completed:  242
# Rows completed:  243
# Rows completed:  244
# Rows completed:  245
# Rows completed:  246
# Rows completed:  247
# Rows completed:  248
# Rows completed:  249
# Rows completed:  250
# Rows completed:  251
# Rows completed:  252
# Rows completed:  253
# Rows completed:  254
# Rows completed:  255
# Rows completed:  256
# Rows completed:  257
# Rows completed:  258
# Rows completed:  259
# Rows completed:  260
# Rows completed:  261
# Rows completed:  262
# Rows completed:  263
# Rows completed:  264
# Rows completed:  265
# Rows completed:  266
# Rows completed:  267
# Rows completed:  268
# Rows completed:  269
# Rows completed:  270
# Rows completed:  271
# Rows completed:  272
# Rows completed:  273
# Rows completed:  274
# Rows completed:  275
# Rows completed:  276
# Rows completed:  277
# Rows completed:  278
# Rows completed:  279
# Rows completed:  280
# Rows completed:  281
# Rows completed:  282
# Rows completed:  283
# Rows completed:  284
# Rows completed:  285
# Rows completed:  286
# Rows completed:  287
# Rows completed:  288
# Rows completed:  289
# Rows completed:  290
# Rows completed:  291
# Rows completed:  292
# Rows completed:  293
# Rows completed:  294
# Rows completed:  295
# Rows completed:  296
# Rows completed:  297
# Rows completed:  298
# Rows completed:  299
# Rows completed:  300
# Rows completed:  301
# Rows completed:  302
# Rows completed:  303
# Rows completed:  304
# Rows completed:  305
# Rows completed:  306
# Rows completed:  307
# Rows completed:  308
# Rows completed:  309
# Rows completed:  310
# Rows completed:  311
# Rows completed:  312
# Rows completed:  313
# Rows completed:  314
# Rows completed:  315
# Rows completed:  316
# Rows completed:  317
# Rows completed:  318
# Rows completed:  319
# Rows completed:  320
# Rows completed:  321
# Rows completed:  322
# Rows completed:  323
# Rows completed:  324
# Rows completed:  325
# Rows completed:  326
# Rows completed:  327
# Rows completed:  328
# Rows completed:  329
# Rows completed:  330
# Rows completed:  331
# Rows completed:  332
# Rows completed:  333
# Rows completed:  334
# Rows completed:  335
# Rows completed:  336
# Rows completed:  337
# Rows completed:  338
# Rows completed:  339
# Rows completed:  340
# Rows completed:  341
# Rows completed:  342
# Rows completed:  343
# Rows completed:  344
# Rows completed:  345
# Rows completed:  346
# Rows completed:  347
# Rows completed:  348
# Rows completed:  349
# Rows completed:  350
# Rows completed:  351
# Rows completed:  352
# Rows completed:  353
# Rows completed:  354
# Rows completed:  355
# Rows completed:  356
# Rows completed:  357
# Rows completed:  358
# Rows completed:  359
# Rows completed:  360
# Rows completed:  361
# Rows completed:  362
# Rows completed:  363
# Rows completed:  364
# Rows completed:  365
# Rows completed:  366
# Rows completed:  367
# Rows completed:  368
# Rows completed:  369
# Rows completed:  370
# Rows completed:  371
# Rows completed:  372
# Rows completed:  373
# Rows completed:  374
# Rows completed:  375
# Rows completed:  376
# Rows completed:  377
# Rows completed:  378
# Rows completed:  379
# Rows completed:  380
# Rows completed:  381
# Rows completed:  382
# Rows completed:  383
# Rows completed:  384
# Rows completed:  385
# Rows completed:  386
# Rows completed:  387
# Rows completed:  388
# Rows completed:  389
# Rows completed:  390
# Rows completed:  391
# Rows completed:  392
# Rows completed:  393
# Rows completed:  394
# Rows completed:  395
# Rows completed:  396
# Rows completed:  397
# Rows completed:  398
# Rows completed:  399
# Rows completed:  400
# Rows completed:  401
# Rows completed:  402
# Rows completed:  403
# Rows completed:  404
# Rows completed:  405
# Rows completed:  406
# Rows completed:  407
# Rows completed:  408
# Rows completed:  409
# Rows completed:  410
# Rows completed:  411
# Rows completed:  412
# Rows completed:  413
# Rows completed:  414
# Rows completed:  415
# Rows completed:  416
# Rows completed:  417
# Rows completed:  418
# Rows completed:  419
# Rows completed:  420
# Rows completed:  421
# Rows completed:  422
# Rows completed:  423
# Rows completed:  424
# Rows completed:  425
# Rows completed:  426
# Rows completed:  427
# Rows completed:  428
# Rows completed:  429
# Rows completed:  430
# Rows completed:  431
# Rows completed:  432
# Rows completed:  433
# Rows completed:  434
# Rows completed:  435
# Rows completed:  436
# Rows completed:  437
# Rows completed:  438
# Rows completed:  439
# Rows completed:  440
# Rows completed:  441
# Rows completed:  442
# Rows completed:  443
# Rows completed:  444
# Rows completed:  445
# Rows completed:  446
# Rows completed:  447
# Rows completed:  448
# Rows completed:  449
# Rows completed:  450
# Rows completed:  451
# Rows completed:  452
# Rows completed:  453
# Rows completed:  454
# Rows completed:  455
# Rows completed:  456
# Rows completed:  457
# Rows completed:  458
# Rows completed:  459
# Rows completed:  460
# Rows completed:  461
# Rows completed:  462
# Rows completed:  463
# Rows completed:  464
# Rows completed:  465
# Rows completed:  466
# Rows completed:  467
# Rows completed:  468
# Rows completed:  469
# Rows completed:  470
# Rows completed:  471
# Rows completed:  472
# Rows completed:  473
# Rows completed:  474
# Rows completed:  475
# Rows completed:  476
# Rows completed:  477
# Rows completed:  478
# Rows completed:  479
# Rows completed:  480
# Rows completed:  481
# Rows completed:  482
# Rows completed:  483
# Rows completed:  484
# Rows completed:  485
# Rows completed:  486
# Rows completed:  487
# Rows completed:  488
# Rows completed:  489
# Rows completed:  490
# Rows completed:  491
# Rows completed:  492
# Rows completed:  493
# Rows completed:  494
# Rows completed:  495
# Rows completed:  496
# Rows completed:  497
# Rows completed:  498
# Rows completed:  499
# Rows completed:  500
# Rows completed:  501
# Rows completed:  502
# Rows completed:  503
# Rows completed:  504
# Rows completed:  505
# Rows completed:  506
# Rows completed:  507
# Rows completed:  508
# Rows completed:  509
# Rows completed:  510
# Rows completed:  511
# Rows completed:  512
# Rows completed:  513
# Rows completed:  514
# Rows completed:  515
# Rows completed:  516
# Rows completed:  517
# Rows completed:  518
# Rows completed:  519
# Rows completed:  520
# Rows completed:  521
# Rows completed:  522
# Rows completed:  523
# Rows completed:  524
# Rows completed:  525
# Rows completed:  526
# Rows completed:  527
# Rows completed:  528
# Rows completed:  529
# Rows completed:  530
# Rows completed:  531
# Rows completed:  532
# Rows completed:  533
# Rows completed:  534
# Rows completed:  535
# Rows completed:  536
# Rows completed:  537
# Rows completed:  538
# Rows completed:  539
# Rows completed:  540
# Rows completed:  541
# Rows completed:  542
# Rows completed:  543
# Rows completed:  544
# Rows completed:  545
# Rows completed:  546
# Rows completed:  547
# Rows completed:  548
# Rows completed:  549
# Rows completed:  550
# Rows completed:  551
# Rows completed:  552
# Rows completed:  553
# Rows completed:  554
# Rows completed:  555
# Rows completed:  556
# Rows completed:  557
# Rows completed:  558
# Rows completed:  559
# Rows completed:  560
# Rows completed:  561
# Rows completed:  562
# Rows completed:  563
# Rows completed:  564
# Rows completed:  565
# Rows completed:  566
# Rows completed:  567
# Rows completed:  568
# Rows completed:  569
# Rows completed:  570
# Rows completed:  571
# Rows completed:  572
# Rows completed:  573
# Rows completed:  574
# Rows completed:  575
# Rows completed:  576
# Rows completed:  577
# Rows completed:  578
# Rows completed:  579
# Rows completed:  580
# Rows completed:  581
# Rows completed:  582
# Rows completed:  583
# Rows completed:  584
# Rows completed:  585
# Rows completed:  586
# Rows completed:  587
# Rows completed:  588
# Rows completed:  589
# Rows completed:  590
# Rows completed:  591
# Rows completed:  592
# Rows completed:  593
# Rows completed:  594
# Rows completed:  595
# Rows completed:  596
# Rows completed:  597
# Rows completed:  598
# Rows completed:  599
# Rows completed:  600
# Rows completed:  601
# Rows completed:  602
# Rows completed:  603
# Rows completed:  604
# Rows completed:  605
# Rows completed:  606
# Rows completed:  607
# Rows completed:  608
# Rows completed:  609
# Rows completed:  610
# Rows completed:  611
# Rows completed:  612
# Rows completed:  613
# Rows completed:  614
# Rows completed:  615
# Rows completed:  616
# Rows completed:  617
# Rows completed:  618
# Rows completed:  619
# Rows completed:  620
# Rows completed:  621
# Rows completed:  622
# Rows completed:  623
# Rows completed:  624
# Rows completed:  625
# Rows completed:  626
# Rows completed:  627
# Rows completed:  628
# Rows completed:  629
# Rows completed:  630
# Rows completed:  631
# Rows completed:  632
# Rows completed:  633
# Rows completed:  634
# Rows completed:  635
# Rows completed:  636
# Rows completed:  637
# Rows completed:  638
# Rows completed:  639
# Rows completed:  640
# Rows completed:  641
# Rows completed:  642
# Rows completed:  643
# Rows completed:  644
# Rows completed:  645
# Rows completed:  646
# Rows completed:  647
# Rows completed:  648
# Rows completed:  649
# Rows completed:  650
# Rows completed:  651
# Rows completed:  652
# Rows completed:  653
# Rows completed:  654
# Rows completed:  655
# Rows completed:  656
# Rows completed:  657
# Rows completed:  658
# Rows completed:  659
# Rows completed:  660
# Rows completed:  661
# Rows completed:  662
# Rows completed:  663
# Rows completed:  664
# Rows completed:  665
# Rows completed:  666
# Rows completed:  667
# Rows completed:  668
# Rows completed:  669
# Rows completed:  670
# Rows completed:  671
# Rows completed:  672
# Rows completed:  673
# Rows completed:  674
# Rows completed:  675
# Rows completed:  676
# Rows completed:  677
# Rows completed:  678
# Rows completed:  679
# Rows completed:  680
# Rows completed:  681
# Rows completed:  682
# Rows completed:  683
# Rows completed:  684
# Rows completed:  685
# Rows completed:  686
# Rows completed:  687
# Rows completed:  688
# Rows completed:  689
# Rows completed:  690
# Rows completed:  691
# Rows completed:  692
# Rows completed:  693
# Rows completed:  694
# Rows completed:  695
# Rows completed:  696
# Rows completed:  697
# Rows completed:  698
# Rows completed:  699
# Rows completed:  700
# Rows completed:  701
# Rows completed:  702
# Rows completed:  703
# Rows completed:  704
# Rows completed:  705
# Rows completed:  706
# Rows completed:  707
# Rows completed:  708
# Rows completed:  709
# Rows completed:  710
# Rows completed:  711
# Rows completed:  712
# Rows completed:  713
# Rows completed:  714
# Rows completed:  715
# Rows completed:  716
# Rows completed:  717
# Rows completed:  718
# Rows completed:  719
# Rows completed:  720
# Rows completed:  721
# Rows completed:  722
# Rows completed:  723
# Rows completed:  724
# Rows completed:  725
# Rows completed:  726
# Rows completed:  727
# Rows completed:  728
# Rows completed:  729
# Rows completed:  730
# Rows completed:  731
# Rows completed:  732
# Rows completed:  733
# Rows completed:  734
# Rows completed:  735
# Rows completed:  736
# Rows completed:  737
# Rows completed:  738
# Rows completed:  739
# Rows completed:  740
# Rows completed:  741
# Rows completed:  742
# Rows completed:  743
# Rows completed:  744
# Rows completed:  745
# Rows completed:  746
# Rows completed:  747
# Rows completed:  748
# Rows completed:  749
# Rows completed:  750
# Rows completed:  751
# Rows completed:  752
# Rows completed:  753
# Rows completed:  754
# Rows completed:  755
# Rows completed:  756
# Rows completed:  757
# Rows completed:  758
# Rows completed:  759
# Rows completed:  760
# Rows completed:  761
# Rows completed:  762
# Rows completed:  763
# Rows completed:  764
# Rows completed:  765
# Rows completed:  766
# Rows completed:  767
# Rows completed:  768
# Rows completed:  769
# Rows completed:  770
# Rows completed:  771
# Rows completed:  772
# Rows completed:  773
# Rows completed:  774
# Rows completed:  775
# Rows completed:  776
# Rows completed:  777
# Rows completed:  778
# Rows completed:  779
# Rows completed:  780
# Rows completed:  781
# Rows completed:  782
# Rows completed:  783
# Rows completed:  784
# Rows completed:  785
# Rows completed:  786
# Rows completed:  787
# Rows completed:  788
# Rows completed:  789
# Rows completed:  790
# Rows completed:  791
# Rows completed:  792
# Rows completed:  793
# Rows completed:  794
# Rows completed:  795
# Rows completed:  796
# Rows completed:  797
# Rows completed:  798
# Rows completed:  799
# Rows completed:  800
# Rows completed:  801
# Rows completed:  802
# Rows completed:  803
# Rows completed:  804
# Rows completed:  805
# Rows completed:  806
# Rows completed:  807
# Rows completed:  808
# Rows completed:  809
# Rows completed:  810
# Rows completed:  811
# Rows completed:  812
# Rows completed:  813
# Rows completed:  814
# Rows completed:  815
# Rows completed:  816
# Rows completed:  817
# Rows completed:  818
# Rows completed:  819
# Rows completed:  820
# Rows completed:  821
# Rows completed:  822
# Rows completed:  823
# Rows completed:  824
# Rows completed:  825
# Rows completed:  826
# Rows completed:  827
# Rows completed:  828
# Rows completed:  829
# Rows completed:  830
# Rows completed:  831
# Rows completed:  832
# Rows completed:  833
# Rows completed:  834
# Rows completed:  835
# Rows completed:  836
# Rows completed:  837
# Rows completed:  838
# Rows completed:  839
# Rows completed:  840
# Rows completed:  841
# Rows completed:  842
# Rows completed:  843
# Rows completed:  844
# Rows completed:  845
# Rows completed:  846
# Rows completed:  847
# Rows completed:  848
# Rows completed:  849
# Rows completed:  850
# Rows completed:  851
# Rows completed:  852
# Rows completed:  853
# Rows completed:  854
# Rows completed:  855
# Rows completed:  856
# Rows completed:  857
# Rows completed:  858
# Rows completed:  859
# Rows completed:  860
# Rows completed:  861
# Rows completed:  862
# Rows completed:  863
# Rows completed:  864
# Rows completed:  865
# Rows completed:  866
# Rows completed:  867
# Rows completed:  868
# Rows completed:  869
# Rows completed:  870
# Rows completed:  871
# Rows completed:  872
# Rows completed:  873
# Rows completed:  874
# Rows completed:  875
# Rows completed:  876
# Rows completed:  877
# Rows completed:  878
# Rows completed:  879
# Rows completed:  880
# Rows completed:  881
# Rows completed:  882
# Rows completed:  883
# Rows completed:  884
# Rows completed:  885
# Rows completed:  886
# Rows completed:  887
# Rows completed:  888
# Rows completed:  889
# Rows completed:  890
# Rows completed:  891
# Rows completed:  892
# Rows completed:  893
# Rows completed:  894
# Rows completed:  895
# Rows completed:  896
# Rows completed:  897
# Rows completed:  898
# Rows completed:  899
# Rows completed:  900
# Rows completed:  901
# Rows completed:  902
# Rows completed:  903
# Rows completed:  904
# Rows completed:  905
# Rows completed:  906
# Rows completed:  907
# Rows completed:  908
# Rows completed:  909
# Rows completed:  910
# Rows completed:  911
# Rows completed:  912
# Rows completed:  913
# Rows completed:  914
# Rows completed:  915
# Rows completed:  916
# Rows completed:  917
# Rows completed:  918
# Rows completed:  919
# Rows completed:  920
# Rows completed:  921
# Rows completed:  922
# Rows completed:  923
# Rows completed:  924
# Rows completed:  925
# Rows completed:  926
# Rows completed:  927
# Rows completed:  928
# Rows completed:  929
# Rows completed:  930
# Rows completed:  931
# Rows completed:  932
# Rows completed:  933
# Rows completed:  934
# Rows completed:  935
# Rows completed:  936
# Rows completed:  937
# Rows completed:  938
# Rows completed:  939
# Rows completed:  940
# Rows completed:  941
# Rows completed:  942
# Rows completed:  943
# Rows completed:  944
# Rows completed:  945
# Rows completed:  946
# Rows completed:  947
# Rows completed:  948
# Rows completed:  949
# Rows completed:  950
# Rows completed:  951
# Rows completed:  952
# Rows completed:  953
# Rows completed:  954
# Rows completed:  955
# Rows completed:  956
# Rows completed:  957
# Rows completed:  958
# Rows completed:  959
# Rows completed:  960
# Rows completed:  961
# Rows completed:  962
# Rows completed:  963
# Rows completed:  964
# Rows completed:  965
# Rows completed:  966
# Rows completed:  967
# Rows completed:  968
# Rows completed:  969
# Rows completed:  970
# Rows completed:  971
# Rows completed:  972
# Rows completed:  973
# Rows completed:  974
# Rows completed:  975
# Rows completed:  976
# Rows completed:  977
# Rows completed:  978
# Rows completed:  979
# Rows completed:  980
# Rows completed:  981
# Rows completed:  982
# Rows completed:  983
# Rows completed:  984
# Rows completed:  985
# Rows completed:  986
# Rows completed:  987
# Rows completed:  988
# Rows completed:  989
# Rows completed:  990
# Rows completed:  991
# Rows completed:  992
# Rows completed:  993
# Rows completed:  994
# Rows completed:  995
# Rows completed:  996
# Rows completed:  997
# Rows completed:  998
# Rows completed:  999
# Rows completed:  1000
# Rows completed:  1001
# Rows completed:  1002
# Rows completed:  1003
# Rows completed:  1004
# Rows completed:  1005
# Rows completed:  1006
# Rows completed:  1007
# Rows completed:  1008
# Rows completed:  1009
# Rows completed:  1010
# Rows completed:  1011
# Rows completed:  1012
# Rows completed:  1013
# Rows completed:  1014
# Rows completed:  1015
# Rows completed:  1016
# Rows completed:  1017
# Rows completed:  1018
# Rows completed:  1019
# Rows completed:  1020
# Rows completed:  1021
# Rows completed:  1022
# Rows completed:  1023
# Rows completed:  1024
# Rows completed:  1025
# Rows completed:  1026
# Rows completed:  1027
# Rows completed:  1028
# Rows completed:  1029
# Rows completed:  1030
# Rows completed:  1031
# Rows completed:  1032
# Rows completed:  1033
# Rows completed:  1034
# Rows completed:  1035
# Rows completed:  1036
# Rows completed:  1037
# Rows completed:  1038
# Rows completed:  1039
# Rows completed:  1040
# Rows completed:  1041
# Rows completed:  1042
# Rows completed:  1043
# Rows completed:  1044
# Rows completed:  1045
# Rows completed:  1046
# Rows completed:  1047
# Rows completed:  1048
# Rows completed:  1049
# Rows completed:  1050
# Rows completed:  1051
# Rows completed:  1052
# Rows completed:  1053
# Rows completed:  1054
# Rows completed:  1055
# Rows completed:  1056
# Rows completed:  1057
# Rows completed:  1058
# Rows completed:  1059
# Rows completed:  1060
# Rows completed:  1061
# Rows completed:  1062
# Rows completed:  1063
# Rows completed:  1064
# Rows completed:  1065
# Rows completed:  1066
# Rows completed:  1067
# Rows completed:  1068
# Rows completed:  1069
# Rows completed:  1070
# Rows completed:  1071
# Rows completed:  1072
# Rows completed:  1073
# Rows completed:  1074
# Rows completed:  1075
# Rows completed:  1076
# Rows completed:  1077
# Rows completed:  1078
# Rows completed:  1079
# Rows completed:  1080
# Rows completed:  1081
# Rows completed:  1082
# Rows completed:  1083
# Rows completed:  1084
# Rows completed:  1085
# Rows completed:  1086
# Rows completed:  1087
# Rows completed:  1088
# Rows completed:  1089
# Rows completed:  1090
# Rows completed:  1091
# Rows completed:  1092
# Rows completed:  1093
# Rows completed:  1094
# Rows completed:  1095
# Rows completed:  1096
# Rows completed:  1097
# Rows completed:  1098
# Rows completed:  1099
# Rows completed:  1100
# Rows completed:  1101
# Rows completed:  1102
# Rows completed:  1103
# Rows completed:  1104
# Rows completed:  1105
# Rows completed:  1106
# Rows completed:  1107
# Rows completed:  1108
# Rows completed:  1109
# Rows completed:  1110
# Rows completed:  1111
# Rows completed:  1112
# Rows completed:  1113
# Rows completed:  1114
# Rows completed:  1115
# Rows completed:  1116
# Rows completed:  1117
# Rows completed:  1118
# Rows completed:  1119
# Rows completed:  1120
# Rows completed:  1121
# Rows completed:  1122
# Rows completed:  1123
# Rows completed:  1124
# Rows completed:  1125
# Rows completed:  1126
# Rows completed:  1127
# Rows completed:  1128
# Rows completed:  1129
# Rows completed:  1130
# Rows completed:  1131
# Rows completed:  1132
# Rows completed:  1133
# Rows completed:  1134
# Rows completed:  1135
# Rows completed:  1136
# Rows completed:  1137
# Rows completed:  1138
# Rows completed:  1139
# Rows completed:  1140
# Rows completed:  1141
# Rows completed:  1142
# Rows completed:  1143
# Rows completed:  1144
# Rows completed:  1145
# Rows completed:  1146
# Rows completed:  1147
# Rows completed:  1148
# Rows completed:  1149
# Rows completed:  1150
# Rows completed:  1151
# Rows completed:  1152
# Rows completed:  1153
# Rows completed:  1154
# Rows completed:  1155
# Rows completed:  1156
# Rows completed:  1157
# Rows completed:  1158
# Rows completed:  1159
# Rows completed:  1160
# Rows completed:  1161
# Rows completed:  1162
# Rows completed:  1163
# Rows completed:  1164
# Rows completed:  1165
# Rows completed:  1166
# Rows completed:  1167
# Rows completed:  1168
# Rows completed:  1169
# Rows completed:  1170
# Rows completed:  1171
# Rows completed:  1172
# Rows completed:  1173
# Rows completed:  1174
# Rows completed:  1175
# Rows completed:  1176
# Rows completed:  1177
# Rows completed:  1178
# Rows completed:  1179
# Rows completed:  1180
# Rows completed:  1181
# Rows completed:  1182
# Rows completed:  1183
# Rows completed:  1184
# Rows completed:  1185
# Rows completed:  1186
# Rows completed:  1187
# Rows completed:  1188
# Rows completed:  1189
# Rows completed:  1190
# Rows completed:  1191
# Rows completed:  1192
# Rows completed:  1193
# Rows completed:  1194
# Rows completed:  1195
# Rows completed:  1196
# Rows completed:  1197
# Rows completed:  1198
# Rows completed:  1199
# Rows completed:  1200
# Rows completed:  1201
# Rows completed:  1202
# Rows completed:  1203
# Rows completed:  1204
# Rows completed:  1205
# Rows completed:  1206
# Rows completed:  1207
# Rows completed:  1208
# Rows completed:  1209
# Rows completed:  1210
# Rows completed:  1211
# Rows completed:  1212
# Rows completed:  1213
# Rows completed:  1214
# Rows completed:  1215
# Rows completed:  1216
# Rows completed:  1217
# Rows completed:  1218
# Rows completed:  1219
# Rows completed:  1220
# Rows completed:  1221
# Rows completed:  1222
# Rows completed:  1223
# Rows completed:  1224
# Rows completed:  1225
# Rows completed:  1226
# Rows completed:  1227
# Rows completed:  1228
# Rows completed:  1229
# Rows completed:  1230
# Rows completed:  1231
# Rows completed:  1232
# Rows completed:  1233
# Rows completed:  1234
# Rows completed:  1235
# Rows completed:  1236
# Rows completed:  1237
# Rows completed:  1238
# Rows completed:  1239
# Rows completed:  1240
# Rows completed:  1241
# Rows completed:  1242
# Rows completed:  1243
# Rows completed:  1244
# Rows completed:  1245
# Rows completed:  1246
# Rows completed:  1247
# Rows completed:  1248
# Rows completed:  1249
# Rows completed:  1250
# Rows completed:  1251
# Rows completed:  1252
# Rows completed:  1253
# Rows completed:  1254
# Rows completed:  1255
# Rows completed:  1256
# Rows completed:  1257
# Rows completed:  1258
# Rows completed:  1259
# Rows completed:  1260
# Rows completed:  1261
# Rows completed:  1262
# Rows completed:  1263
# Rows completed:  1264
# Rows completed:  1265
# Rows completed:  1266
# Rows completed:  1267
# Rows completed:  1268
# Rows completed:  1269
# Rows completed:  1270
# Rows completed:  1271
# Rows completed:  1272
# Rows completed:  1273
# Rows completed:  1274
# Rows completed:  1275
# Rows completed:  1276
# Rows completed:  1277
# Rows completed:  1278
# Rows completed:  1279
# Rows completed:  1280
# Rows completed:  1281
# Rows completed:  1282
# Rows completed:  1283
# Rows completed:  1284
# Rows completed:  1285
# Rows completed:  1286
# Rows completed:  1287
# Rows completed:  1288
# Rows completed:  1289
# Rows completed:  1290
# Rows completed:  1291
# Rows completed:  1292
# Rows completed:  1293
# Rows completed:  1294
# Rows completed:  1295
# Rows completed:  1296
# Rows completed:  1297
# Rows completed:  1298
# Rows completed:  1299
# Rows completed:  1300
# Rows completed:  1301
# Rows completed:  1302
# Rows completed:  1303
# Rows completed:  1304
# Rows completed:  1305
# Rows completed:  1306
# Rows completed:  1307
# Rows completed:  1308
# Rows completed:  1309
# Rows completed:  1310
# Rows completed:  1311
# Rows completed:  1312
# Rows completed:  1313
# Rows completed:  1314
# Rows completed:  1315
# Rows completed:  1316
# Rows completed:  1317
# Rows completed:  1318
# Rows completed:  1319
# Rows completed:  1320
# Rows completed:  1321
# Rows completed:  1322
# Rows completed:  1323
# Rows completed:  1324
# Rows completed:  1325
# Rows completed:  1326
# Rows completed:  1327
# Rows completed:  1328
# Rows completed:  1329
# Rows completed:  1330
# Rows completed:  1331
# Rows completed:  1332
# Rows completed:  1333
# Rows completed:  1334
# Rows completed:  1335
# Rows completed:  1336
# Rows completed:  1337
# Rows completed:  1338
# Rows completed:  1339
# Rows completed:  1340
# Rows completed:  1341
# Rows completed:  1342
# Rows completed:  1343
# Rows completed:  1344
# Rows completed:  1345
# Rows completed:  1346
# Rows completed:  1347
# Rows completed:  1348
# Rows completed:  1349
# Rows completed:  1350
# Rows completed:  1351
# Rows completed:  1352
# Rows completed:  1353
# Rows completed:  1354
# Rows completed:  1355
# Rows completed:  1356
# Rows completed:  1357
# Rows completed:  1358
# Rows completed:  1359
# Rows completed:  1360
# Rows completed:  1361
# Rows completed:  1362
# Rows completed:  1363
# Rows completed:  1364
# Rows completed:  1365
# Rows completed:  1366
# Rows completed:  1367
# Rows completed:  1368
# Rows completed:  1369
# Rows completed:  1370
# Rows completed:  1371
# Rows completed:  1372
# Rows completed:  1373
# Rows completed:  1374
# Rows completed:  1375
# Rows completed:  1376
# Rows completed:  1377
# Rows completed:  1378
# Rows completed:  1379
# Rows completed:  1380
# Rows completed:  1381
# Rows completed:  1382
# Rows completed:  1383
# Rows completed:  1384
# Rows completed:  1385
# Rows completed:  1386
# Rows completed:  1387
# Rows completed:  1388
# Rows completed:  1389
# Rows completed:  1390
# Rows completed:  1391
# Rows completed:  1392
# Rows completed:  1393
# Rows completed:  1394
# Rows completed:  1395
# Rows completed:  1396
# Rows completed:  1397
# Rows completed:  1398
# Rows completed:  1399
# Rows completed:  1400
# Rows completed:  1401
# Rows completed:  1402
# Rows completed:  1403
# Rows completed:  1404
# Rows completed:  1405
# Rows completed:  1406
# Rows completed:  1407
# Rows completed:  1408
# Rows completed:  1409
# Rows completed:  1410
# Rows completed:  1411
# Rows completed:  1412
# Rows completed:  1413
# Rows completed:  1414
# Rows completed:  1415
# Rows completed:  1416
# Rows completed:  1417
# Rows completed:  1418
# Rows completed:  1419
# Rows completed:  1420
# Rows completed:  1421
# Rows completed:  1422
# Rows completed:  1423
# Rows completed:  1424
# Rows completed:  1425
# Rows completed:  1426
# Rows completed:  1427
# Rows completed:  1428
# Rows completed:  1429
# Rows completed:  1430
# Rows completed:  1431
# Rows completed:  1432
# Rows completed:  1433
# Rows completed:  1434
# Rows completed:  1435
# Rows completed:  1436
# Rows completed:  1437
# Rows completed:  1438
# Rows completed:  1439
# Rows completed:  1440
# Rows completed:  1441
# Rows completed:  1442
# Rows completed:  1443
# Rows completed:  1444
# Rows completed:  1445
# Rows completed:  1446
# Rows completed:  1447
# Rows completed:  1448
# Rows completed:  1449
# Rows completed:  1450
# Rows completed:  1451
# Rows completed:  1452
# Rows completed:  1453
# Rows completed:  1454
# Rows completed:  1455
# Rows completed:  1456
# Rows completed:  1457
# Rows completed:  1458
# Rows completed:  1459
# Rows completed:  1460
# Rows completed:  1461
# Rows completed:  1462
# Rows completed:  1463
# Rows completed:  1464
# Rows completed:  1465
# Rows completed:  1466
# Rows completed:  1467
# Rows completed:  1468
# Rows completed:  1469
# Rows completed:  1470
# Rows completed:  1471
# Rows completed:  1472
# Rows completed:  1473
# Rows completed:  1474
# Rows completed:  1475
# Rows completed:  1476
# Rows completed:  1477
# Rows completed:  1478
# Rows completed:  1479
# Rows completed:  1480
# Rows completed:  1481
# Rows completed:  1482
# Rows completed:  1483
# Rows completed:  1484
# Rows completed:  1485
# Rows completed:  1486
# Rows completed:  1487
# Rows completed:  1488
# Rows completed:  1489
# Rows completed:  1490
# Rows completed:  1491
# Rows completed:  1492
# Rows completed:  1493
# Rows completed:  1494
# Rows completed:  1495
# Rows completed:  1496
# Rows completed:  1497
# Rows completed:  1498
# Rows completed:  1499
# Rows completed:  1500
# Rows completed:  1501
# Rows completed:  1502
# Rows completed:  1503
# Rows completed:  1504
# Rows completed:  1505
# Rows completed:  1506
# Rows completed:  1507
# Rows completed:  1508
# Rows completed:  1509
# Rows completed:  1510
# Rows completed:  1511
# Rows completed:  1512
# Rows completed:  1513
# Rows completed:  1514
# Rows completed:  1515
# Rows completed:  1516
# Rows completed:  1517
# Rows completed:  1518
# Rows completed:  1519
# Rows completed:  1520
# Rows completed:  1521
# Rows completed:  1522
# Rows completed:  1523
# Rows completed:  1524
# Rows completed:  1525
# Rows completed:  1526
# Rows completed:  1527
# Rows completed:  1528
# Rows completed:  1529
# Rows completed:  1530
# Rows completed:  1531
# Rows completed:  1532
# Rows completed:  1533
# Rows completed:  1534
# Rows completed:  1535
# Rows completed:  1536
# Rows completed:  1537
# Rows completed:  1538
# Rows completed:  1539
# Rows completed:  1540
# Rows completed:  1541
# Rows completed:  1542
# Rows completed:  1543
# Rows completed:  1544
# Rows completed:  1545
# Rows completed:  1546
# Rows completed:  1547
# Rows completed:  1548
# Rows completed:  1549
# Rows completed:  1550
# Rows completed:  1551
# Rows completed:  1552
# Rows completed:  1553
# Rows completed:  1554
# Rows completed:  1555
# Rows completed:  1556
# Rows completed:  1557
# Rows completed:  1558
# Rows completed:  1559
# Rows completed:  1560
# Rows completed:  1561
# Rows completed:  1562
# Rows completed:  1563
# Rows completed:  1564
# Rows completed:  1565
# Rows completed:  1566
# Rows completed:  1567
# Rows completed:  1568
# Rows completed:  1569
# Rows completed:  1570
# Rows completed:  1571
# Rows completed:  1572
# Rows completed:  1573
# Rows completed:  1574
# Rows completed:  1575
# Rows completed:  1576
# Rows completed:  1577
# Rows completed:  1578
# Rows completed:  1579
# Rows completed:  1580
# Rows completed:  1581
# Rows completed:  1582
# Rows completed:  1583
# Rows completed:  1584
# Rows completed:  1585
# Rows completed:  1586
# Rows completed:  1587
# Rows completed:  1588
# Rows completed:  1589
# Rows completed:  1590
# Rows completed:  1591
# Rows completed:  1592
# Rows completed:  1593
# Rows completed:  1594
# Rows completed:  1595
# Rows completed:  1596
# Rows completed:  1597
# Rows completed:  1598
# Rows completed:  1599
# Rows completed:  1600
# Rows completed:  1601
# Rows completed:  1602
# Rows completed:  1603
# Rows completed:  1604
# Rows completed:  1605
# Rows completed:  1606
# Rows completed:  1607
# Rows completed:  1608
# Rows completed:  1609
# Rows completed:  1610
# Rows completed:  1611
# Rows completed:  1612
# Rows completed:  1613
# Rows completed:  1614
# Rows completed:  1615
# Rows completed:  1616
# Rows completed:  1617
# Rows completed:  1618
# Rows completed:  1619
# Rows completed:  1620
# Rows completed:  1621
# Rows completed:  1622
# Rows completed:  1623
# Rows completed:  1624
# Rows completed:  1625
# Rows completed:  1626
# Rows completed:  1627
# Rows completed:  1628
# Rows completed:  1629
# Rows completed:  1630
# Rows completed:  1631
# Rows completed:  1632
# Rows completed:  1633
# Rows completed:  1634
# Rows completed:  1635
# Rows completed:  1636
# Rows completed:  1637
# Rows completed:  1638
# Rows completed:  1639
# Rows completed:  1640
# Rows completed:  1641
# Rows completed:  1642
# Rows completed:  1643
# Rows completed:  1644
# Rows completed:  1645
# Rows completed:  1646
# Rows completed:  1647
# Rows completed:  1648
# Rows completed:  1649
# Rows completed:  1650
# Rows completed:  1651
# Rows completed:  1652
# Rows completed:  1653
# Rows completed:  1654
# Rows completed:  1655
# Rows completed:  1656
# Rows completed:  1657
# Rows completed:  1658
# Rows completed:  1659
# Rows completed:  1660
# Rows completed:  1661
# Rows completed:  1662
# Rows completed:  1663
# Rows completed:  1664
# Rows completed:  1665
# Rows completed:  1666
# Rows completed:  1667
# Rows completed:  1668
# Rows completed:  1669
# Rows completed:  1670
# Rows completed:  1671
# Rows completed:  1672
# Rows completed:  1673
# Rows completed:  1674
# Rows completed:  1675
# Rows completed:  1676
# Rows completed:  1677
# Rows completed:  1678
# Rows completed:  1679
# Rows completed:  1680
# Rows completed:  1681
# Rows completed:  1682
# Rows completed:  1683
# Rows completed:  1684
# Rows completed:  1685
# Rows completed:  1686
# Rows completed:  1687
# Rows completed:  1688
# Rows completed:  1689
# Rows completed:  1690
# Rows completed:  1691
# Rows completed:  1692
# Rows completed:  1693
# Rows completed:  1694
# Rows completed:  1695
# Rows completed:  1696
# Rows completed:  1697
# Rows completed:  1698
# Rows completed:  1699
# Rows completed:  1700
# Rows completed:  1701
# Rows completed:  1702
# Rows completed:  1703
# Rows completed:  1704
# Rows completed:  1705
# Rows completed:  1706
# Rows completed:  1707
# Rows completed:  1708
# Rows completed:  1709
# Rows completed:  1710
# Rows completed:  1711
# Rows completed:  1712
# Rows completed:  1713
# Rows completed:  1714
# Rows completed:  1715
# Rows completed:  1716
# Rows completed:  1717
# Rows completed:  1718
# Rows completed:  1719
# Rows completed:  1720
# Rows completed:  1721
# Rows completed:  1722
# Rows completed:  1723
# Rows completed:  1724
# Rows completed:  1725
# Rows completed:  1726
# Rows completed:  1727
# Rows completed:  1728
# Rows completed:  1729
# Rows completed:  1730
# Rows completed:  1731
# Rows completed:  1732
# Rows completed:  1733
# Rows completed:  1734
# Rows completed:  1735
# Rows completed:  1736
# Rows completed:  1737
# Rows completed:  1738
# Rows completed:  1739
# Rows completed:  1740
# Rows completed:  1741
# Rows completed:  1742
# Rows completed:  1743
# Rows completed:  1744
# Rows completed:  1745
# Rows completed:  1746
# Rows completed:  1747
# Rows completed:  1748
# Rows completed:  1749
# Rows completed:  1750
# Rows completed:  1751
# Rows completed:  1752
# Rows completed:  1753
# Rows completed:  1754
# Rows completed:  1755
# Rows completed:  1756
# Rows completed:  1757
# Rows completed:  1758
# Rows completed:  1759
# Rows completed:  1760
# Rows completed:  1761
# Rows completed:  1762
# Rows completed:  1763
# Rows completed:  1764
# Rows completed:  1765
# Rows completed:  1766
# Rows completed:  1767
# Rows completed:  1768
# Rows completed:  1769
# Rows completed:  1770
# Rows completed:  1771
# Rows completed:  1772
# Rows completed:  1773
# Rows completed:  1774
# Rows completed:  1775
# Rows completed:  1776
# Rows completed:  1777
# Rows completed:  1778
# Rows completed:  1779
# Rows completed:  1780
# Rows completed:  1781
# Rows completed:  1782
# Rows completed:  1783
# Rows completed:  1784
# Rows completed:  1785
# Rows completed:  1786
# Rows completed:  1787
# Rows completed:  1788
# Rows completed:  1789
# Rows completed:  1790
# Rows completed:  1791
# Rows completed:  1792
# Rows completed:  1793
# Rows completed:  1794
# Rows completed:  1795
# Rows completed:  1796
# Rows completed:  1797
# Rows completed:  1798
# Rows completed:  1799
# Rows completed:  1800
# Rows completed:  1801
# Rows completed:  1802
# Rows completed:  1803
# Rows completed:  1804
# Rows completed:  1805
# Rows completed:  1806
# Rows completed:  1807
# Rows completed:  1808
# Rows completed:  1809
# Rows completed:  1810
# Rows completed:  1811
# Rows completed:  1812
# Rows completed:  1813
# Rows completed:  1814
# Rows completed:  1815
# Rows completed:  1816
# Rows completed:  1817
# Rows completed:  1818
# Rows completed:  1819
# Rows completed:  1820
# Rows completed:  1821
# Rows completed:  1822
# Rows completed:  1823
# Rows completed:  1824
# Rows completed:  1825
# Rows completed:  1826
# Rows completed:  1827
# Rows completed:  1828
# Rows completed:  1829
# Rows completed:  1830
# Rows completed:  1831
# Rows completed:  1832
# Rows completed:  1833
# Rows completed:  1834
# Rows completed:  1835
# Rows completed:  1836
# Rows completed:  1837
# Rows completed:  1838
# Rows completed:  1839
# Rows completed:  1840
# Rows completed:  1841
# Rows completed:  1842
# Rows completed:  1843
# Rows completed:  1844
# Rows completed:  1845
# Rows completed:  1846
# Rows completed:  1847
# Rows completed:  1848
# Rows completed:  1849
# Rows completed:  1850
# Rows completed:  1851
# Rows completed:  1852
# Rows completed:  1853
# Rows completed:  1854
# Rows completed:  1855
# Rows completed:  1856
# Rows completed:  1857
# Rows completed:  1858
# Rows completed:  1859
# Rows completed:  1860
# Rows completed:  1861
# Rows completed:  1862
# Rows completed:  1863
# Rows completed:  1864
# Rows completed:  1865
# Rows completed:  1866
# Rows completed:  1867
# Rows completed:  1868
# Rows completed:  1869
# Rows completed:  1870
# Rows completed:  1871
# Rows completed:  1872
# Rows completed:  1873
# Rows completed:  1874
# Rows completed:  1875
# Rows completed:  1876
# Rows completed:  1877
# Rows completed:  1878
# Rows completed:  1879
# Rows completed:  1880
# Rows completed:  1881
# Rows completed:  1882
# Rows completed:  1883
# Rows completed:  1884
# Rows completed:  1885
# Rows completed:  1886
# Rows completed:  1887
# Rows completed:  1888
# Rows completed:  1889
# Rows completed:  1890
# Rows completed:  1891
# Rows completed:  1892
# Rows completed:  1893
# Rows completed:  1894
# Rows completed:  1895
# Rows completed:  1896
# Rows completed:  1897
# Rows completed:  1898
# Rows completed:  1899
# Rows completed:  1900
# Rows completed:  1901
# Rows completed:  1902
# Rows completed:  1903
# Rows completed:  1904
# Rows completed:  1905
# Rows completed:  1906
# Rows completed:  1907
# Rows completed:  1908
# Rows completed:  1909
# Rows completed:  1910
# Rows completed:  1911
# Rows completed:  1912
# Rows completed:  1913
# Rows completed:  1914
# Rows completed:  1915
# Rows completed:  1916
# Rows completed:  1917
# Rows completed:  1918
# Rows completed:  1919
# Rows completed:  1920
# Rows completed:  1921
# Rows completed:  1922
# Rows completed:  1923
# Rows completed:  1924
# Rows completed:  1925
# Rows completed:  1926
# Rows completed:  1927
# Rows completed:  1928
# Rows completed:  1929
# Rows completed:  1930
# Rows completed:  1931
# Rows completed:  1932
# Rows completed:  1933
# Rows completed:  1934
# Rows completed:  1935
# Rows completed:  1936
# Rows completed:  1937
# Rows completed:  1938
# Rows completed:  1939
# Rows completed:  1940
# Rows completed:  1941
# Rows completed:  1942
# Rows completed:  1943
# Rows completed:  1944
# Rows completed:  1945
# Rows completed:  1946
# Rows completed:  1947
# Rows completed:  1948
# Rows completed:  1949
# Rows completed:  1950
# Rows completed:  1951
# Rows completed:  1952
# Rows completed:  1953
# Rows completed:  1954
# Rows completed:  1955
# Rows completed:  1956
# Rows completed:  1957
# Rows completed:  1958
# Rows completed:  1959
# Rows completed:  1960
# Rows completed:  1961
# Rows completed:  1962
# Rows completed:  1963
# Rows completed:  1964
# Rows completed:  1965
# Rows completed:  1966
# Rows completed:  1967
# Rows completed:  1968
# Rows completed:  1969
# Rows completed:  1970
# Rows completed:  1971
# Rows completed:  1972
# Rows completed:  1973
# Rows completed:  1974
# Rows completed:  1975
# Rows completed:  1976
# Rows completed:  1977
# Rows completed:  1978
# Rows completed:  1979
# Rows completed:  1980
# Rows completed:  1981
# Rows completed:  1982
# Rows completed:  1983
# Rows completed:  1984
# Rows completed:  1985
# Rows completed:  1986
# Rows completed:  1987
# Rows completed:  1988
# Rows completed:  1989
# Rows completed:  1990
# Rows completed:  1991
# Rows completed:  1992
# Rows completed:  1993
# Rows completed:  1994
# Rows completed:  1995
# Rows completed:  1996
# Rows completed:  1997
# Rows completed:  1998
# Rows completed:  1999
# Rows completed:  2000
# Rows completed:  2001
# Rows completed:  2002
# Rows completed:  2003
# Rows completed:  2004
# Rows completed:  2005
# Rows completed:  2006
# Rows completed:  2007
# Rows completed:  2008
# Rows completed:  2009
# Rows completed:  2010
# Rows completed:  2011
# Rows completed:  2012
# Rows completed:  2013
# Rows completed:  2014
# Rows completed:  2015
# Rows completed:  2016
# Rows completed:  2017
# Rows completed:  2018
# Rows completed:  2019
# Rows completed:  2020
# Rows completed:  2021
# Rows completed:  2022
# Rows completed:  2023
# Rows completed:  2024
# Rows completed:  2025
# Rows completed:  2026
# Rows completed:  2027
# Rows completed:  2028
# Rows completed:  2029
# Rows completed:  2030
# Rows completed:  2031
# Rows completed:  2032
# Rows completed:  2033
# Rows completed:  2034
# Rows completed:  2035
# Rows completed:  2036
# Rows completed:  2037
# Rows completed:  2038
# Rows completed:  2039
# Rows completed:  2040
# Rows completed:  2041
# Rows completed:  2042
# Rows completed:  2043
# Rows completed:  2044
# Rows completed:  2045
# Rows completed:  2046
# Rows completed:  2047
# Rows completed:  2048
# Rows completed:  2049
# Rows completed:  2050
# Rows completed:  2051
# Rows completed:  2052
# Rows completed:  2053
# Rows completed:  2054
# Rows completed:  2055
# Rows completed:  2056
# Rows completed:  2057
# Rows completed:  2058
# Rows completed:  2059
# Rows completed:  2060
# Rows completed:  2061
# Rows completed:  2062
# Rows completed:  2063
# Rows completed:  2064
# Rows completed:  2065
# Rows completed:  2066
# Rows completed:  2067
# Rows completed:  2068
# Rows completed:  2069
# Rows completed:  2070
# Rows completed:  2071
# Rows completed:  2072
# Rows completed:  2073
# Rows completed:  2074
# Rows completed:  2075
# Rows completed:  2076
# Rows completed:  2077
# Rows completed:  2078
# Rows completed:  2079
# Rows completed:  2080
# Rows completed:  2081
# Rows completed:  2082
# Rows completed:  2083
# Rows completed:  2084
# Rows completed:  2085
# Rows completed:  2086
# Rows completed:  2087
# Rows completed:  2088
# Rows completed:  2089
# Rows completed:  2090
# Rows completed:  2091
# Rows completed:  2092
# Rows completed:  2093
# Rows completed:  2094
# Rows completed:  2095
# Rows completed:  2096
# Rows completed:  2097
# Rows completed:  2098
# Rows completed:  2099
# Rows completed:  2100
# Rows completed:  2101
# Rows completed:  2102
# Rows completed:  2103
# Rows completed:  2104
# Rows completed:  2105
# Rows completed:  2106
# Rows completed:  2107
# Rows completed:  2108
# Rows completed:  2109
# Rows completed:  2110
# Rows completed:  2111
# Rows completed:  2112
# Rows completed:  2113
# Rows completed:  2114
# Rows completed:  2115
# Rows completed:  2116
# Rows completed:  2117
# Rows completed:  2118
# Rows completed:  2119
# Rows completed:  2120
# Rows completed:  2121
# Rows completed:  2122
# Rows completed:  2123
# Rows completed:  2124
# Rows completed:  2125
# Rows completed:  2126
# Rows completed:  2127
# Rows completed:  2128
# Rows completed:  2129
# Rows completed:  2130
# Rows completed:  2131
# Rows completed:  2132
# Rows completed:  2133
# Rows completed:  2134
# Rows completed:  2135
# Rows completed:  2136
# Rows completed:  2137
# Rows completed:  2138
# Rows completed:  2139
# Rows completed:  2140
# Rows completed:  2141
# Rows completed:  2142
# Rows completed:  2143
# Rows completed:  2144
# Rows completed:  2145
# Rows completed:  2146
# Rows completed:  2147
# Rows completed:  2148
# Rows completed:  2149
# Rows completed:  2150
# Rows completed:  2151
# Rows completed:  2152
# Rows completed:  2153
# Rows completed:  2154
# Rows completed:  2155
# Rows completed:  2156
# Rows completed:  2157
# Rows completed:  2158
# Rows completed:  2159
# Rows completed:  2160
# Rows completed:  2161
# Rows completed:  2162
# Rows completed:  2163
# Rows completed:  2164
# Rows completed:  2165
# Rows completed:  2166
# Rows completed:  2167
# Rows completed:  2168
# Rows completed:  2169
# Rows completed:  2170
# Rows completed:  2171
# Rows completed:  2172
# Rows completed:  2173
# Rows completed:  2174
# Rows completed:  2175
# Rows completed:  2176
# Rows completed:  2177
# Rows completed:  2178
# Rows completed:  2179
# Rows completed:  2180
# Rows completed:  2181
# Rows completed:  2182
# Rows completed:  2183
# Rows completed:  2184
# Rows completed:  2185
# Rows completed:  2186
# Rows completed:  2187
# Rows completed:  2188
# Rows completed:  2189
# Rows completed:  2190
# Rows completed:  2191
# Rows completed:  2192
# Rows completed:  2193
# Rows completed:  2194
# Rows completed:  2195
# Rows completed:  2196
# Rows completed:  2197
# Rows completed:  2198
# Rows completed:  2199
# Rows completed:  2200
# Rows completed:  2201
# Rows completed:  2202
# Rows completed:  2203
# Rows completed:  2204
# Rows completed:  2205
# Rows completed:  2206
# Rows completed:  2207
# Rows completed:  2208
# Rows completed:  2209
# Rows completed:  2210
# Rows completed:  2211
# Rows completed:  2212
# Rows completed:  2213
# Rows completed:  2214
# Rows completed:  2215
# Rows completed:  2216
# Rows completed:  2217
# Rows completed:  2218
# Rows completed:  2219
# Rows completed:  2220
# Rows completed:  2221
# Rows completed:  2222
# Rows completed:  2223
# Rows completed:  2224
# Rows completed:  2225
# Rows completed:  2226
# Rows completed:  2227
# Rows completed:  2228
# Rows completed:  2229
# Rows completed:  2230
# Rows completed:  2231
# Rows completed:  2232
# ...
# Rows completed:  2975
# Rows completed:  2976
# Rows completed:  2977
# Rows completed:  2978
# Rows completed:  2979
# Rows completed:  2980
# Rows completed:  2981
# Rows completed:  2982
# Rows completed:  2983
# Rows completed:  2984
# Rows completed:  2985
# Rows completed:  2986
# Rows completed:  2987
# Rows completed:  2988
# Rows completed:  2989
# Rows completed:  2990
# Rows completed:  2991
# Rows completed:  2992
# Rows completed:  2993
# Rows completed:  2994
# Rows completed:  2995
# Rows completed:  2996
# Rows completed:  2997
# Rows completed:  2998
# Rows completed:  2999
# Rows completed:  3000
# Rows completed:  3001
# Rows completed:  3002
# Rows completed:  3003
# Rows completed:  3004
# Rows completed:  3005
# Rows completed:  3006
# Rows completed:  3007
# Rows completed:  3008
# Rows completed:  3009
# Rows completed:  3010
# Rows completed:  3011
# Rows completed:  3012
# Rows completed:  3013
# Rows completed:  3014
# Rows completed:  3015
# Rows completed:  3016
# Rows completed:  3017
# Rows completed:  3018
# Rows completed:  3019
# Rows completed:  3020
# Rows completed:  3021
# Rows completed:  3022
# Rows completed:  3023
# Rows completed:  3024
# Rows completed:  3025
# Rows completed:  3026
# Rows completed:  3027
# Rows completed:  3028
# Rows completed:  3029
# Rows completed:  3030
# Rows completed:  3031
# Rows completed:  3032
# Rows completed:  3033
# Rows completed:  3034
# Rows completed:  3035
# Rows completed:  3036
# Rows completed:  3037
# Rows completed:  3038
# Rows completed:  3039
# Rows completed:  3040
# Rows completed:  3041
# Rows completed:  3042
# Rows completed:  3043
# Rows completed:  3044
# Rows completed:  3045
# Rows completed:  3046
# Rows completed:  3047
# Rows completed:  3048
# Rows completed:  3049
# Rows completed:  3050
# Rows completed:  3051
# Rows completed:  3052
# Rows completed:  3053
# Rows completed:  3054
# Rows completed:  3055
# Rows completed:  3056
# Rows completed:  3057
# Rows completed:  3058
# Rows completed:  3059
# Rows completed:  3060
# Rows completed:  3061
# Rows completed:  3062
# Rows completed:  3063
# Rows completed:  3064
# Rows completed:  3065
# Rows completed:  3066
# Rows completed:  3067
# Rows completed:  3068
# Rows completed:  3069
# Rows completed:  3070
# Rows completed:  3071
# Rows completed:  3072
# Rows completed:  3073
# Rows completed:  3074
# Rows completed:  3075
# Rows completed:  3076
# Rows completed:  3077
# Rows completed:  3078
# Rows completed:  3079
# Rows completed:  3080
# Rows completed:  3081
# Rows completed:  3082
# Rows completed:  3083
# Rows completed:  3084
# Rows completed:  3085
# Rows completed:  3086
# Rows completed:  3087
# Rows completed:  3088
# Rows completed:  3089
# Rows completed:  3090
# Rows completed:  3091
# Rows completed:  3092
# Rows completed:  3093
# Rows completed:  3094
# Rows completed:  3095
# Rows completed:  3096
# Rows completed:  3097
# Rows completed:  3098
# Rows completed:  3099
# Rows completed:  3100
# Rows completed:  3101
# Rows completed:  3102
# Rows completed:  3103
# Rows completed:  3104
# Rows completed:  3105
# Rows completed:  3106
# Rows completed:  3107
# Rows completed:  3108
# Rows completed:  3109
# Rows completed:  3110
# Rows completed:  3111
# Rows completed:  3112
# Rows completed:  3113
# Rows completed:  3114
# Rows completed:  3115
# Rows completed:  3116
# Rows completed:  3117
# Rows completed:  3118
# Rows completed:  3119
# Rows completed:  3120
# Rows completed:  3121
# Rows completed:  3122
# Rows completed:  3123
# Rows completed:  3124
# Rows completed:  3125
# Rows completed:  3126
# Rows completed:  3127
# Rows completed:  3128
# Rows completed:  3129
# Rows completed:  3130
# Rows completed:  3131
# Rows completed:  3132
# Rows completed:  3133
# Rows completed:  3134
# Rows completed:  3135
# Rows completed:  3136
# Rows completed:  3137
# Rows completed:  3138
# Rows completed:  3139
# Rows completed:  3140
# Rows completed:  3141
# Rows completed:  3142
# Rows completed:  3143
# Rows completed:  3144
# Rows completed:  3145
# Rows completed:  3146
# Rows completed:  3147
# Rows completed:  3148
# Rows completed:  3149
# Rows completed:  3150
# Rows completed:  3151
# Rows completed:  3152
# Rows completed:  3153
# Rows completed:  3154
# Rows completed:  3155
# Rows completed:  3156
# Rows completed:  3157
# Rows completed:  3158
# Rows completed:  3159
# Rows completed:  3160
# Rows completed:  3161
# Rows completed:  3162
# Rows completed:  3163
# Rows completed:  3164
# Rows completed:  3165
# Rows completed:  3166
# Rows completed:  3167
# Rows completed:  3168
# Rows completed:  3169
# Rows completed:  3170
# Rows completed:  3171
# Rows completed:  3172
# Rows completed:  3173
# Rows completed:  3174
# Rows completed:  3175
# Rows completed:  3176
# Rows completed:  3177
# Rows completed:  3178
# Rows completed:  3179
# Rows completed:  3180
# Rows completed:  3181
# Rows completed:  3182
# Rows completed:  3183
# Rows completed:  3184
# Rows completed:  3185
# Rows completed:  3186
# Rows completed:  3187
# Rows completed:  3188
# Rows completed:  3189
# Rows completed:  3190
# Rows completed:  3191
# Rows completed:  3192
# Rows completed:  3193
# Rows completed:  3194
# Rows completed:  3195
# Rows completed:  3196
# Rows completed:  3197
# Rows completed:  3198
# Rows completed:  3199
# Rows completed:  3200
# Rows completed:  3201
# Rows completed:  3202
# Rows completed:  3203
# Rows completed:  3204
# Rows completed:  3205
# Rows completed:  3206
# Rows completed:  3207
# Rows completed:  3208
# Rows completed:  3209
# Rows completed:  3210
# Rows completed:  3211
# Rows completed:  3212
# Rows completed:  3213
# Rows completed:  3214
# Rows completed:  3215
# Rows completed:  3216
# Rows completed:  3217
# Rows completed:  3218
# Rows completed:  3219
# Rows completed:  3220
# Rows completed:  3221
# Rows completed:  3222
# Rows completed:  3223
# Rows completed:  3224
# Rows completed:  3225
# Rows completed:  3226
# Rows completed:  3227
# Rows completed:  3228
# Rows completed:  3229
# Rows completed:  3230
# Rows completed:  3231
# Rows completed:  3232
# Rows completed:  3233
# Rows completed:  3234
# Rows completed:  3235
# Rows completed:  3236
# Rows completed:  3237
# Rows completed:  3238
# Rows completed:  3239
# Rows completed:  3240
# Rows completed:  3241
# Rows completed:  3242
# Rows completed:  3243
# Rows completed:  3244
# Rows completed:  3245
# Rows completed:  3246
# Rows completed:  3247
# Rows completed:  3248
# Rows completed:  3249
# Rows completed:  3250
# Rows completed:  3251
# Rows completed:  3252
# Rows completed:  3253
# Rows completed:  3254
# Rows completed:  3255
# Rows completed:  3256
# Rows completed:  3257
# Rows completed:  3258
# Rows completed:  3259
# Rows completed:  3260
# Rows completed:  3261
# Rows completed:  3262
# Rows completed:  3263
# Rows completed:  3264
# Rows completed:  3265
# Rows completed:  3266
# Rows completed:  3267
# Rows completed:  3268
# Rows completed:  3269
# Rows completed:  3270
# Rows completed:  3271
# Rows completed:  3272
# Rows completed:  3273
# Rows completed:  3274
# Rows completed:  3275
# Rows completed:  3276
# Rows completed:  3277
# Rows completed:  3278
# Rows completed:  3279
# Rows completed:  3280
# Rows completed:  3281
# Rows completed:  3282
# Rows completed:  3283
# Rows completed:  3284
# Rows completed:  3285
# Rows completed:  3286
# Rows completed:  3287
# Rows completed:  3288
# Rows completed:  3289
# Rows completed:  3290
# Rows completed:  3291
# Rows completed:  3292
# Rows completed:  3293
# Rows completed:  3294
# Rows completed:  3295
# Rows completed:  3296
# Rows completed:  3297
# Rows completed:  3298
# Rows completed:  3299
# Rows completed:  3300
# Rows completed:  3301
# Rows completed:  3302
# Rows completed:  3303
# Rows completed:  3304
# Rows completed:  3305
# Rows completed:  3306
# Rows completed:  3307
# Rows completed:  3308
# Rows completed:  3309
# Rows completed:  3310
# Rows completed:  3311
# Rows completed:  3312
# Rows completed:  3313
# Rows completed:  3314
# Rows completed:  3315
# Rows completed:  3316
# Rows completed:  3317
# Rows completed:  3318
# Rows completed:  3319
# Rows completed:  3320
# Rows completed:  3321
# Rows completed:  3322
# Rows completed:  3323
# Rows completed:  3324
# Rows completed:  3325
# Rows completed:  3326
# Rows completed:  3327
# Rows completed:  3328
# Rows completed:  3329
# Rows completed:  3330
# Rows completed:  3331
# Percent intra-TAD:  0.750994035785
# Percent overlapping with TAD boundary (not counted in inter/intra):  0.395977184029
#        chrA   startbpA     endbpA   chrB   startbpB     endbpB  score  \
# 0      chr1   85270000   85280000   chr1   87480000   87490000    805
# 1     chr11  117100000  117110000  chr11  117210000  117220000    246
# 2     chr11   66920000   66930000  chr11   67160000   67170000    233
# 3     chr11   77630000   77640000  chr11   77780000   77790000    222
# 4     chr11  116180000  116190000  chr11  116300000  116310000    203
# 5     chr11  118910000  118920000  chr11  119050000  119060000    200
# 6     chr17   39980000   39990000  chr17   71310000   71320000    200
# 7     chr11  100430000  100440000  chr11  100560000  100570000    188
# 8      chr2   26300000   26310000   chr2   26410000   26420000    185
# 9     chr11   78830000   78840000  chr11   79020000   79030000    178
# 10    chr11   11710000   11720000  chr11   11870000   11880000    177
# 11    chr11   95250000   95260000  chr11   95380000   95390000    175
# 12    chr11  103870000  103880000  chr11  104020000  104030000    175
# 13    chr16   10410000   10420000  chr16   10520000   10530000    174
# 14    chr11   53950000   53960000  chr11   54060000   54070000    173
# 15    chr11   76060000   76070000  chr11   76210000   76220000    173
# 16    chr11   87870000   87880000  chr11   88000000   88010000    173
# 17     chr2   27140000   27150000   chr2   27270000   27280000    166
# 18     chr9   45220000   45230000   chr9   45330000   45340000    165
# 19     chr3  145710000  145720000   chr3  145840000  145850000    162
# 20    chr11   74990000   75000000  chr11   75100000   75110000    162
# 21    chr11   79390000   79400000  chr11   79500000   79510000    160
# 22    chr16   10880000   10890000  chr16   11030000   11040000    160
# 23    chr11  117740000  117750000  chr11  117880000  117890000    159
# 24     chr4  154460000  154470000   chr4  154620000  154630000    158
# 25    chr16   57240000   57250000  chr16   57390000   57400000    158
# 26    chr15   79780000   79790000  chr15   79900000   79910000    155
# 27     chr1  183820000  183830000   chr1  184040000  184050000    154
# 28     chr8  123200000  123210000   chr8  123310000  123320000    152
# 29    chr15  102810000  102820000  chr15  103000000  103010000    152
# ...     ...        ...        ...    ...        ...        ...    ...
# 3301   chr1  187360000  187370000   chr1  188530000  188540000     18
# 3302   chr3  100770000  100780000   chr3  101610000  101620000     18
# 3303   chr4   14880000   14890000   chr4   15240000   15250000     18
# 3304   chr5   27390000   27400000   chr5   27940000   27950000     18
# 3305   chr8   46530000   46540000   chr8   47020000   47030000     18
# 3306  chr13   68300000   68310000  chr13   68600000   68610000     18
# 3307  chr17   34140000   34150000  chr17   35430000   35440000     18
# 3308  chr18   62410000   62420000  chr18   62830000   62840000     18
# 3309  chr18   68080000   68090000  chr18   68610000   68620000     18
# 3310  chr18   80200000   80210000  chr18   80640000   80650000     18
# 3311   chr1  187510000  187520000   chr1  188520000  188530000     17
# 3312   chr7   50660000   50670000   chr7   52040000   52050000     17
# 3313   chr9   32390000   32400000   chr9   33050000   33060000     17
# 3314  chr15   34130000   34140000  chr15  102270000  102280000     17
# 3315  chr15   39180000   39190000  chr15   39670000   39680000     17
# 3316  chr16   85790000   85800000  chr16   86880000   86890000     17
# 3317  chr17   13390000   13400000  chr17   13700000   13710000     17
# 3318   chrX  139890000  139900000   chrX  140100000  140110000     17
# 3319   chr5   82070000   82080000   chr5   82410000   82420000     16
# 3320   chr7   69370000   69380000   chr7   69520000   69530000     16
# 3321   chr7   83530000   83540000   chr7   84080000   84090000     16
# 3322  chr13  110850000  110860000  chr13  111150000  111160000     16
# 3323  chr14   76280000   76290000  chr14   76870000   76880000     16
# 3324  chr14  104430000  104440000  chr14  105210000  105220000     16
# 3325  chr11    4370000    4380000  chr11    6060000    6070000     15
# 3326  chr11   52000000   52010000  chr11   52280000   52290000     15
# 3327  chr11   53370000   53380000  chr11   53840000   53850000     15
# 3328  chr15   30460000   30470000  chr15  102270000  102280000     15
# 3329   chrX  162610000  162620000   chrX  163080000  163090000     15
# 3330   chr4  145710000  145720000   chr4  148980000  148990000     14
#
#               tadA          tadB regA regB Int_Status
# 0      ID_0.01_159   ID_0.01_159    P    P     intraN
# 1     ID_0.01_3838  ID_0.01_3838    P    P     intraN
# 2              NaN  ID_0.01_3626   EP    P    interEP
# 3              NaN  ID_0.01_3676    P    P     interN
# 4     ID_0.01_3833  ID_0.01_3833   EP    P    intraEP
# 5     ID_0.01_3847  ID_0.01_3847    P   EP    intraEP
# 6     ID_0.01_5181  ID_0.01_5246    P   EP    interEP
# 7              NaN  ID_0.01_3766    P    P     interN
# 8      ID_0.01_471   ID_0.01_471   EP   EP    intraEP
# 9     ID_0.01_3683                 EP
# 10    ID_0.01_3483
# 11    ID_0.01_3736
# 12    ID_0.01_3786  ID_0.01_3786
# 13    ID_0.01_4881  ID_0.01_4881
# 14    ID_0.01_3580  ID_0.01_3580
# 15    ID_0.01_3667  ID_0.01_3667
# 16    ID_0.01_3718  ID_0.01_3718
# 17     ID_0.01_475   ID_0.01_475
# 18    ID_0.01_2919  ID_0.01_2919
# 19    ID_0.01_1149  ID_0.01_1149
# 20    ID_0.01_3662  ID_0.01_3662
# 21             NaN  ID_0.01_3686
# 22    ID_0.01_4883
# 23    ID_0.01_3841  ID_0.01_3841
# 24    ID_0.01_1511
# 25    ID_0.01_5010
# 26    ID_0.01_4781  ID_0.01_4781
# 27     ID_0.01_376   ID_0.01_376
# 28    ID_0.01_2799  ID_0.01_2799
# 29    ID_0.01_4862
# ...            ...           ...  ...  ...        ...
# 3301   ID_0.01_389   ID_0.01_389
# 3302           NaN  ID_0.01_1052
# 3303           NaN
# 3304  ID_0.01_1552  ID_0.01_1552
# 3305  ID_0.01_2642  ID_0.01_2643
# 3306  ID_0.01_4268  ID_0.01_4268
# 3307  ID_0.01_5167  ID_0.01_5175
# 3308           NaN  ID_0.01_5430
# 3309  ID_0.01_5448  ID_0.01_5450
# 3310  ID_0.01_5480  ID_0.01_5480
# 3311   ID_0.01_389   ID_0.01_389
# 3312  ID_0.01_2300  ID_0.01_2307
# 3313           NaN  ID_0.01_2886
# 3314  ID_0.01_4680  ID_0.01_4857
# 3315           NaN  ID_0.01_4698
# 3316  ID_0.01_5029  ID_0.01_5029
# 3317  ID_0.01_5100  ID_0.01_5100
# 3318           NaN  ID_0.01_5774
# 3319  ID_0.01_1665  ID_0.01_1665
# 3320  ID_0.01_2334  ID_0.01_2334
# 3321  ID_0.01_2364  ID_0.01_2364
# 3322  ID_0.01_4366  ID_0.01_4366
# 3323  ID_0.01_4569
# 3324           NaN  ID_0.01_4604
# 3325  ID_0.01_3467  ID_0.01_3474
# 3326  ID_0.01_3572  ID_0.01_3574
# 3327  ID_0.01_3577  ID_0.01_3579
# 3328  ID_0.01_4672  ID_0.01_4857
# 3329  ID_0.01_5798  ID_0.01_5798
# 3330  ID_0.01_1482  ID_0.01_1492
#
# [3331 rows x 12 columns]

# %%
	regFile = '/data2/josh/expCH12/mm9_regulatory_converted.bed'
	regs = pd.read_table(regFile)
	regs.columns = ["chr", "startbp", "endbp", "feature_type", "extra1", "extra2"]
	addEPCols(regs, tadLabeledLoops)
# Out:
# has TADs
# intraN
# Rows completed:  1
# has TADs
# intraN
# Rows completed:  2
# is Tadless
# tadlessEP
# Rows completed:  3
# is Tadless
# tadlessN
# Rows completed:  4
# has TADs
# intraEP
# Rows completed:  5
# has TADs
# intraEP
# Rows completed:  6
# has TADs
# interEP
# Rows completed:  7
# is Tadless
# tadlessN
# Rows completed:  8
# has TADs
# intraEP
# Rows completed:  9
# has TADs
# interEP
# Rows completed:  10
# has TADs
# interN
# Rows completed:  11
# has TADs
# interEP
# Rows completed:  12
# has TADs
# intraEP
# Rows completed:  13
# has TADs
# intraEP
# Rows completed:  14
# has TADs
# intraEP
# Rows completed:  15
# has TADs
# intraEP
# Rows completed:  16
# has TADs
# intraN
# Rows completed:  17
# has TADs
# intraEP
# Rows completed:  18
# has TADs
# intraN
# Rows completed:  19
# has TADs
# intraEP
# Rows completed:  20
# has TADs
# intraEP
# Rows completed:  21
# is Tadless
# tadlessN
# Rows completed:  22
# has TADs
# interEP
# Rows completed:  23
# has TADs
# intraEP
# Rows completed:  24
# has TADs
# interN
# Rows completed:  25
# has TADs
# interEP
# Rows completed:  26
# has TADs
# intraEP
# Rows completed:  27
# has TADs
# intraEP
# Rows completed:  28
# has TADs
# intraEP
# Rows completed:  29
# has TADs
# interN
# Rows completed:  30
# has TADs
# intraEP
# Rows completed:  31
# is Tadless
# tadlessEP
# Rows completed:  32
# is Tadless
# tadlessN
# Rows completed:  33
# is Tadless
# tadlessEP
# Rows completed:  34
# is Tadless
# tadlessN
# Rows completed:  35
# has TADs
# intraEP
# Rows completed:  36
# has TADs
# intraEP
# Rows completed:  37
# has TADs
# intraEP
# Rows completed:  38
# has TADs
# intraN
# Rows completed:  39
# has TADs
# intraEP
# Rows completed:  40
# has TADs
# intraEP
# Rows completed:  41
# has TADs
# intraEP
# Rows completed:  42
# has TADs
# interN
# Rows completed:  43
# has TADs
# intraEP
# Rows completed:  44
# has TADs
# intraEP
# Rows completed:  45
# has TADs
# intraN
# Rows completed:  46
# has TADs
# intraEP
# Rows completed:  47
# has TADs
# intraN
# Rows completed:  48
# has TADs
# intraN
# Rows completed:  49
# is Tadless
# tadlessEP
# Rows completed:  50
# has TADs
# intraEP
# Rows completed:  51
# has TADs
# intraEP
# Rows completed:  52
# has TADs
# intraEP
# Rows completed:  53
# has TADs
# interEP
# Rows completed:  54
# has TADs
# intraEP
# Rows completed:  55
# has TADs
# intraEP
# Rows completed:  56
# has TADs
# intraN
# Rows completed:  57
# has TADs
# intraEP
# Rows completed:  58
# has TADs
# intraEP
# Rows completed:  59
# has TADs
# intraEP
# Rows completed:  60
# has TADs
# intraN
# Rows completed:  61
# has TADs
# intraEP
# Rows completed:  62
# has TADs
# intraEP
# Rows completed:  63
# has TADs
# interEP
# Rows completed:  64
# is Tadless
# tadlessN
# Rows completed:  65
# has TADs
# intraN
# Rows completed:  66
# has TADs
# interEP
# Rows completed:  67
# has TADs
# interN
# Rows completed:  68
# is Tadless
# tadlessEP
# Rows completed:  69
# is Tadless
# tadlessEP
# Rows completed:  70
# has TADs
# intraEP
# Rows completed:  71
# has TADs
# intraEP
# Rows completed:  72
# has TADs
# interN
# Rows completed:  73
# has TADs
# intraEP
# Rows completed:  74
# has TADs
# interEP
# Rows completed:  75
# has TADs
# intraEP
# Rows completed:  76
# is Tadless
# tadlessEP
# Rows completed:  77
# has TADs
# intraEP
# Rows completed:  78
# is Tadless
# tadlessEP
# Rows completed:  79
# has TADs
# intraN
# Rows completed:  80
# has TADs
# interN
# Rows completed:  81
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-541d269f0f65> in <module>()
#       2 regs = pd.read_table(regFile)
#       3 regs.columns = ["chr", "startbp", "endbp", "feature_type", "extra1", "extra2"]
# ----> 4 addEPCols(regs, tadLabeledLoops)
#       5
#
# <ipython-input-119-955110e5d214> in addEPCols(regs, loops)
#     117
#     118                 # regBInfo contains regulatory labels of regions that overlap with the contact point
# --> 119                 regBInfo = regs[(((regs['chr'] == chrB) & (regs['startbp'] < startBpB)                          & (regs['endbp'] > startBpB)) |                                         ((regs['chr'] == chrB) & (regs['startbp'] < endBpB) & (regs['endbp'] > endBpB)) |                                       ((regs['chr'] == chrB) & (regs['startbp'] > startBpB) & (regs['endbp'] < endBpB)))]
#     120
#     121                 regBInfoLen = regBInfo.shape[0]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in na_op(x, y)
#     781
#     782         if is_object_dtype(x.dtype):
# --> 783             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     784         else:
#     785
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in _comp_method_OBJECT_ARRAY(op, x, y)
#     761         result = lib.vec_compare(x, y, op)
#     762     else:
# --> 763         result = lib.scalar_compare(x, y, op)
#     764     return result
#     765
#
# KeyboardInterrupt:

# %%
	loops.to_csv('/data2/josh/expCH12/labeled_loops.csv', index=True, sep='\t', header=True)
